# %% [markdown]
# ## **Installing and Importing**

# %%
import os
# Find the latest version of spark 3.x  from http://www.apache.org/dist/spark/ and enter as the spark version
spark_version = 'spark-3.4.1'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,082 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,347 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,227 kB]
# Get:14 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,143 kB]
# Fetched 6,158 kB in 5s (1,308 kB/s)
# Reading package lists... Done

# %%
# Import packages
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import StructType,StructField,StringType, DateType,IntegerType

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ## Reading CSV and Exploring Data

# %%
#  Import and read the Heart_Disease_Prediction.csv
from pyspark import SparkFiles
url = "https://raw.githubusercontent.com/AleidvdZ/Project4HeartDisease/main/Heart_Disease_Prediction.csv"
spark.sparkContext.addFile(url)
hd_df = spark.read.csv(SparkFiles.get("Heart_Disease_Prediction.csv"), sep=",", header=True)

# Show DataFrame
hd_df.show()
# Out:
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# |index|Age|Sex|Chest pain type| BP|Cholesterol|FBS over 120|EKG results|Max HR|Exercise angina|ST depression|Slope of ST|Number of vessels fluro|Thallium|Heart Disease|
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# |    0| 70|  1|              4|130|        322|           0|          2|   109|              0|          2.4|          2|                      3|       3|     Presence|
# |    1| 67|  0|              3|115|        564|           0|          2|   160|              0|          1.6|          2|                      0|       7|      Absence|
# |    2| 57|  1|              2|124|        261|           0|          0|   141|              0|          0.3|          1|                      0|       7|     Presence|
# |    3| 64|  1|              4|128|        263|           0|          0|   105|              1|          0.2|          2|                      1|       7|      Absence|
# |    4| 74|  0|              2|120|        269|           0|          2|   121|              1|          0.2|          1|                      1|       3|      Absence|
# |    5| 65|  1|              4|120|        177|           0|          0|   140|              0|          0.4|          1|                      0|       7|      Absence|
# |    6| 56|  1|              3|130|        256|           1|          2|   142|              1|          0.6|          2|                      1|       6|     Presence|
# |    7| 59|  1|              4|110|        239|           0|          2|   142|              1|          1.2|          2|                      1|       7|     Presence|
# |    8| 60|  1|              4|140|        293|           0|          2|   170|              0|          1.2|          2|                      2|       7|     Presence|
# |    9| 63|  0|              4|150|        407|           0|          2|   154|              0|          4.0|          2|                      3|       7|     Presence|
# |   10| 59|  1|              4|135|        234|           0|          0|   161|              0|          0.5|          2|                      0|       7|      Absence|
# |   11| 53|  1|              4|142|        226|           0|          2|   111|              1|          0.0|          1|                      0|       7|      Absence|
# |   12| 44|  1|              3|140|        235|           0|          2|   180|              0|          0.0|          1|                      0|       3|      Absence|
# |   13| 61|  1|              1|134|        234|           0|          0|   145|              0|          2.6|          2|                      2|       3|     Presence|
# |   14| 57|  0|              4|128|        303|           0|          2|   159|              0|          0.0|          1|                      1|       3|      Absence|
# |   15| 71|  0|              4|112|        149|           0|          0|   125|              0|          1.6|          2|                      0|       3|      Absence|
# |   16| 46|  1|              4|140|        311|           0|          0|   120|              1|          1.8|          2|                      2|       7|     Presence|
# |   17| 53|  1|              4|140|        203|           1|          2|   155|              1|          3.1|          3|                      0|       7|     Presence|
# |   18| 64|  1|              1|110|        211|           0|          2|   144|              1|          1.8|          2|                      0|       3|      Absence|
# |   19| 40|  1|              1|140|        199|           0|          0|   178|              1|          1.4|          1|                      0|       7|      Absence|
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# only showing top 20 rows

# %%
#Replace whitespaces in column headers with underscore
from pyspark.sql import functions as F

hd_df = hd_df.select([F.col(col).alias(col.replace(' ', '_')) for col in hd_df.columns])

hd_df.show()
# Out:
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# |index|Age|Sex|Chest_pain_type| BP|Cholesterol|FBS_over_120|EKG_results|Max_HR|Exercise_angina|ST_depression|Slope_of_ST|Number_of_vessels_fluro|Thallium|Heart_Disease|
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# |    0| 70|  1|              4|130|        322|           0|          2|   109|              0|          2.4|          2|                      3|       3|     Presence|
# |    1| 67|  0|              3|115|        564|           0|          2|   160|              0|          1.6|          2|                      0|       7|      Absence|
# |    2| 57|  1|              2|124|        261|           0|          0|   141|              0|          0.3|          1|                      0|       7|     Presence|
# |    3| 64|  1|              4|128|        263|           0|          0|   105|              1|          0.2|          2|                      1|       7|      Absence|
# |    4| 74|  0|              2|120|        269|           0|          2|   121|              1|          0.2|          1|                      1|       3|      Absence|
# |    5| 65|  1|              4|120|        177|           0|          0|   140|              0|          0.4|          1|                      0|       7|      Absence|
# |    6| 56|  1|              3|130|        256|           1|          2|   142|              1|          0.6|          2|                      1|       6|     Presence|
# |    7| 59|  1|              4|110|        239|           0|          2|   142|              1|          1.2|          2|                      1|       7|     Presence|
# |    8| 60|  1|              4|140|        293|           0|          2|   170|              0|          1.2|          2|                      2|       7|     Presence|
# |    9| 63|  0|              4|150|        407|           0|          2|   154|              0|          4.0|          2|                      3|       7|     Presence|
# |   10| 59|  1|              4|135|        234|           0|          0|   161|              0|          0.5|          2|                      0|       7|      Absence|
# |   11| 53|  1|              4|142|        226|           0|          2|   111|              1|          0.0|          1|                      0|       7|      Absence|
# |   12| 44|  1|              3|140|        235|           0|          2|   180|              0|          0.0|          1|                      0|       3|      Absence|
# |   13| 61|  1|              1|134|        234|           0|          0|   145|              0|          2.6|          2|                      2|       3|     Presence|
# |   14| 57|  0|              4|128|        303|           0|          2|   159|              0|          0.0|          1|                      1|       3|      Absence|
# |   15| 71|  0|              4|112|        149|           0|          0|   125|              0|          1.6|          2|                      0|       3|      Absence|
# |   16| 46|  1|              4|140|        311|           0|          0|   120|              1|          1.8|          2|                      2|       7|     Presence|
# |   17| 53|  1|              4|140|        203|           1|          2|   155|              1|          3.1|          3|                      0|       7|     Presence|
# |   18| 64|  1|              1|110|        211|           0|          2|   144|              1|          1.8|          2|                      0|       3|      Absence|
# |   19| 40|  1|              1|140|        199|           0|          0|   178|              1|          1.4|          1|                      0|       7|      Absence|
# +-----+---+---+---------------+---+-----------+------------+-----------+------+---------------+-------------+-----------+-----------------------+--------+-------------+
# only showing top 20 rows

# %%
cols_to_drop = ['index', 'Exercise_angine', 'Chest_pain_type', 'Max_HR', 'Thallium', 'Slope_of_ST', 'FBS_over_120', 'Number_of_vessels_fluro']
hd_df = hd_df.drop(*cols_to_drop)

hd_df.show()
# Out:
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# |Age|Sex| BP|Cholesterol|EKG_results|Exercise_angina|ST_depression|Heart_Disease|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# | 70|  1|130|        322|          2|              0|          2.4|     Presence|
# | 67|  0|115|        564|          2|              0|          1.6|      Absence|
# | 57|  1|124|        261|          0|              0|          0.3|     Presence|
# | 64|  1|128|        263|          0|              1|          0.2|      Absence|
# | 74|  0|120|        269|          2|              1|          0.2|      Absence|
# | 65|  1|120|        177|          0|              0|          0.4|      Absence|
# | 56|  1|130|        256|          2|              1|          0.6|     Presence|
# | 59|  1|110|        239|          2|              1|          1.2|     Presence|
# | 60|  1|140|        293|          2|              0|          1.2|     Presence|
# | 63|  0|150|        407|          2|              0|          4.0|     Presence|
# | 59|  1|135|        234|          0|              0|          0.5|      Absence|
# | 53|  1|142|        226|          2|              1|          0.0|      Absence|
# | 44|  1|140|        235|          2|              0|          0.0|      Absence|
# | 61|  1|134|        234|          0|              0|          2.6|     Presence|
# | 57|  0|128|        303|          2|              0|          0.0|      Absence|
# | 71|  0|112|        149|          0|              0|          1.6|      Absence|
# | 46|  1|140|        311|          0|              1|          1.8|     Presence|
# | 53|  1|140|        203|          2|              1|          3.1|     Presence|
# | 64|  1|110|        211|          2|              1|          1.8|      Absence|
# | 40|  1|140|        199|          0|              1|          1.4|      Absence|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import when, col
hd_df = hd_df.withColumn("Heart_Disease", when(col("Heart_Disease") == "Presence", 1).when(col("Heart_Disease") == "Absence", 0).otherwise(col("Heart_Disease")))

# Display the DataFrame
hd_df.show()
# Out:
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# |Age|Sex| BP|Cholesterol|EKG_results|Exercise_angina|ST_depression|Heart_Disease|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# | 70|  1|130|        322|          2|              0|          2.4|            1|
# | 67|  0|115|        564|          2|              0|          1.6|            0|
# | 57|  1|124|        261|          0|              0|          0.3|            1|
# | 64|  1|128|        263|          0|              1|          0.2|            0|
# | 74|  0|120|        269|          2|              1|          0.2|            0|
# | 65|  1|120|        177|          0|              0|          0.4|            0|
# | 56|  1|130|        256|          2|              1|          0.6|            1|
# | 59|  1|110|        239|          2|              1|          1.2|            1|
# | 60|  1|140|        293|          2|              0|          1.2|            1|
# | 63|  0|150|        407|          2|              0|          4.0|            1|
# | 59|  1|135|        234|          0|              0|          0.5|            0|
# | 53|  1|142|        226|          2|              1|          0.0|            0|
# | 44|  1|140|        235|          2|              0|          0.0|            0|
# | 61|  1|134|        234|          0|              0|          2.6|            1|
# | 57|  0|128|        303|          2|              0|          0.0|            0|
# | 71|  0|112|        149|          0|              0|          1.6|            0|
# | 46|  1|140|        311|          0|              1|          1.8|            1|
# | 53|  1|140|        203|          2|              1|          3.1|            1|
# | 64|  1|110|        211|          2|              1|          1.8|            0|
# | 40|  1|140|        199|          0|              1|          1.4|            0|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
for col_name in hd_df.columns:
    hd_df = hd_df.withColumn(col_name, col(col_name).cast('integer'))

# Display the DataFrame
hd_df.show()
# Out:
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# |Age|Sex| BP|Cholesterol|EKG_results|Exercise_angina|ST_depression|Heart_Disease|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# | 70|  1|130|        322|          2|              0|            2|            1|
# | 67|  0|115|        564|          2|              0|            1|            0|
# | 57|  1|124|        261|          0|              0|            0|            1|
# | 64|  1|128|        263|          0|              1|            0|            0|
# | 74|  0|120|        269|          2|              1|            0|            0|
# | 65|  1|120|        177|          0|              0|            0|            0|
# | 56|  1|130|        256|          2|              1|            0|            1|
# | 59|  1|110|        239|          2|              1|            1|            1|
# | 60|  1|140|        293|          2|              0|            1|            1|
# | 63|  0|150|        407|          2|              0|            4|            1|
# | 59|  1|135|        234|          0|              0|            0|            0|
# | 53|  1|142|        226|          2|              1|            0|            0|
# | 44|  1|140|        235|          2|              0|            0|            0|
# | 61|  1|134|        234|          0|              0|            2|            1|
# | 57|  0|128|        303|          2|              0|            0|            0|
# | 71|  0|112|        149|          0|              0|            1|            0|
# | 46|  1|140|        311|          0|              1|            1|            1|
# | 53|  1|140|        203|          2|              1|            3|            1|
# | 64|  1|110|        211|          2|              1|            1|            0|
# | 40|  1|140|        199|          0|              1|            1|            0|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# only showing top 20 rows

# %%
# Show schema
hd_df.printSchema()
# Out:
# root
#  |-- Age: integer (nullable = true)
#  |-- Sex: integer (nullable = true)
#  |-- BP: integer (nullable = true)
#  |-- Cholesterol: integer (nullable = true)
#  |-- EKG_results: integer (nullable = true)
#  |-- Exercise_angina: integer (nullable = true)
#  |-- ST_depression: integer (nullable = true)
#  |-- Heart_Disease: integer (nullable = true)

# %%
# Create a temporary view of the DataFrame.
hd_df.createOrReplaceTempView('data')

# Look at data using SparkSQL
spark.sql("select * from data limit 10").show()
# Out:
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# |Age|Sex| BP|Cholesterol|EKG_results|Exercise_angina|ST_depression|Heart_Disease|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# | 70|  1|130|        322|          2|              0|            2|            1|
# | 67|  0|115|        564|          2|              0|            1|            0|
# | 57|  1|124|        261|          0|              0|            0|            1|
# | 64|  1|128|        263|          0|              1|            0|            0|
# | 74|  0|120|        269|          2|              1|            0|            0|
# | 65|  1|120|        177|          0|              0|            0|            0|
# | 56|  1|130|        256|          2|              1|            0|            1|
# | 59|  1|110|        239|          2|              1|            1|            1|
# | 60|  1|140|        293|          2|              0|            1|            1|
# | 63|  0|150|        407|          2|              0|            4|            1|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+

# %% [markdown]
# ## **Machine Learning Model - Neural Network**

# %%
#convert to pandas
pandas_df = hd_df.toPandas()
pandas_df.head()
# Out:
#    Age  Sex   BP  Cholesterol  EKG_results  Exercise_angina  ST_depression  \
# 0   70    1  130          322            2                0              2
# 1   67    0  115          564            2                0              1
# 2   57    1  124          261            0                0              0
# 3   64    1  128          263            0                1              0
# 4   74    0  120          269            2                1              0
#
#    Heart_Disease
# 0              1
# 1              0
# 2              1
# 3              0
# 4              0

# %%
# Create new columns for get_dummies
dummy = ["EKG_results"]
pandas_dummies_df = pd.get_dummies(pandas_df, columns=dummy)
pandas_dummies_df
# Out:
#      Age  Sex   BP  Cholesterol  Exercise_angina  ST_depression  \
# 0     70    1  130          322                0              2
# 1     67    0  115          564                0              1
# 2     57    1  124          261                0              0
# 3     64    1  128          263                1              0
# 4     74    0  120          269                1              0
# ..   ...  ...  ...          ...              ...            ...
# 265   52    1  172          199                0              0
# 266   44    1  120          263                0              0
# 267   56    0  140          294                0              1
# 268   57    1  140          192                0              0
# 269   67    1  160          286                1              1
#
#      Heart_Disease  EKG_results_0  EKG_results_1  EKG_results_2
# 0                1              0              0              1
# 1                0              0              0              1
# 2                1              1              0              0
# 3                0              1              0              0
# 4                0              0              0              1
# ..             ...            ...            ...            ...
# 265              0              1              0              0
# 266              0              1              0              0
# 267              0              0              0              1
# 268              0              1              0              0
# 269              1              0              0              1
#
# [270 rows x 10 columns]

# %% [markdown]
# # **Model**

# %%
#%%python
# Remove Heart Disease target from features data (NOTE: NEED TO UPDATE COLUMNS)
y = pandas_dummies_df['Heart_Disease'].values
X = pandas_dummies_df.drop(columns=["Heart_Disease"]).values

# Split training/test datasets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 80
#
#  dense_1 (Dense)             (None, 3)                 27
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 111 (444.00 Byte)
# Trainable params: 111 (444.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 9ms/step - loss: 0.7493 - accuracy: 0.4455
# Epoch 2/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7438 - accuracy: 0.4356
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7389 - accuracy: 0.4307
# Epoch 4/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7350 - accuracy: 0.4257
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7307 - accuracy: 0.4752
# Epoch 6/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7271 - accuracy: 0.5545
# Epoch 7/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7240 - accuracy: 0.5545
# Epoch 8/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7209 - accuracy: 0.5545
# Epoch 9/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7180 - accuracy: 0.5545
# Epoch 10/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7154 - accuracy: 0.5545
# Epoch 11/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7129 - accuracy: 0.5545
# Epoch 12/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7111 - accuracy: 0.5545
# Epoch 13/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7091 - accuracy: 0.5545
# Epoch 14/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7073 - accuracy: 0.5545
# Epoch 15/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7060 - accuracy: 0.5545
# Epoch 16/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7046 - accuracy: 0.5545
# Epoch 17/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7034 - accuracy: 0.5545
# Epoch 18/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7025 - accuracy: 0.5545
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7015 - accuracy: 0.5545
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7005 - accuracy: 0.5545
# Epoch 21/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6998 - accuracy: 0.5545
# Epoch 22/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6989 - accuracy: 0.5545
# Epoch 23/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6982 - accuracy: 0.5545
# Epoch 24/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6976 - accuracy: 0.5545
# Epoch 25/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6968 - accuracy: 0.5545
# Epoch 26/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.5545
# Epoch 27/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6955 - accuracy: 0.5545
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6950 - accuracy: 0.5545
# Epoch 29/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6946 - accuracy: 0.5545
# Epoch 30/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6941 - accuracy: 0.5545
# Epoch 31/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6938 - accuracy: 0.5545
# Epoch 32/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.5545
# Epoch 33/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5545
# Epoch 34/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5545
# Epoch 35/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5545
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5545
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.5545
# Epoch 38/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 0.5545
# Epoch 39/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6910 - accuracy: 0.5545
# Epoch 40/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6908 - accuracy: 0.5545
# Epoch 41/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6904 - accuracy: 0.5545
# Epoch 42/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6900 - accuracy: 0.5545
# Epoch 43/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.5545
# Epoch 44/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.5545
# Epoch 45/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.5545
# Epoch 46/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.5545
# Epoch 47/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5545
# Epoch 48/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.5545
# Epoch 49/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6877 - accuracy: 0.5545
# Epoch 50/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.5545
# Epoch 51/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5545
# Epoch 52/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 0.5545
# Epoch 53/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6862 - accuracy: 0.5545
# Epoch 54/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6857 - accuracy: 0.5545
# Epoch 55/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.5545
# Epoch 56/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6848 - accuracy: 0.5545
# Epoch 57/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6841 - accuracy: 0.5545
# Epoch 58/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6834 - accuracy: 0.5545
# Epoch 59/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6826 - accuracy: 0.5545
# Epoch 60/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6816 - accuracy: 0.5545
# Epoch 61/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5545
# Epoch 62/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.5545
# Epoch 63/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6784 - accuracy: 0.5545
# Epoch 64/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6770 - accuracy: 0.5545
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6755 - accuracy: 0.5545
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.5545
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.5545
# Epoch 68/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6703 - accuracy: 0.5545
# Epoch 69/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6683 - accuracy: 0.5545
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6658 - accuracy: 0.5545
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6634 - accuracy: 0.5545
# Epoch 72/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6601 - accuracy: 0.5545
# Epoch 73/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.5545
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6532 - accuracy: 0.5545
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6494 - accuracy: 0.5545
# Epoch 76/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6460 - accuracy: 0.5545
# Epoch 77/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6413 - accuracy: 0.5545
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6377 - accuracy: 0.5545
# Epoch 79/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.5545
# Epoch 80/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6295 - accuracy: 0.5545
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6255 - accuracy: 0.5545
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6210 - accuracy: 0.5545
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6172 - accuracy: 0.5545
# Epoch 84/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6130 - accuracy: 0.5545
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.5545
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6055 - accuracy: 0.5545
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6017 - accuracy: 0.5545
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5984 - accuracy: 0.5545
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5953 - accuracy: 0.5545
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5924 - accuracy: 0.5545
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.5545
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5870 - accuracy: 0.5545
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5846 - accuracy: 0.5545
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5823 - accuracy: 0.5545
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5803 - accuracy: 0.5545
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.5545
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.5545
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.6733
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5724 - accuracy: 0.7129
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.7129

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.5719 - accuracy: 0.7500 - 260ms/epoch - 87ms/step
# Loss: 0.5719410181045532, Accuracy: 0.75

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression( random_state=42)
classifier
# Out:
# LogisticRegression(random_state=42)

# %%
# Train the data
classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7673267326732673
# Testing Data Score: 0.7352941176470589

# %%
predictions = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results.head(10)
# Out:
#    Prediction  Actual
# 0           1       1
# 1           0       1
# 2           1       0
# 3           0       0
# 4           1       0
# 5           0       0
# 6           1       1
# 7           1       1
# 8           0       0
# 9           0       1

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           28           10
# Actual 1            8           22
# Accuracy Score : 0.7352941176470589
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76        38
#            1       0.69      0.73      0.71        30
#
#     accuracy                           0.74        68
#    macro avg       0.73      0.74      0.73        68
# weighted avg       0.74      0.74      0.74        68

# %% [markdown]
# ### **Random Forest**

# %%
#Decision Tree modeling
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           31            7
# Actual 1            7           23
# Accuracy Score : 0.7941176470588235
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        38
#            1       0.77      0.77      0.77        30
#
#     accuracy                           0.79        68
#    macro avg       0.79      0.79      0.79        68
# weighted avg       0.79      0.79      0.79        68

# %% [markdown]
# ### **Feature Importance**

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
X = pandas_df.copy()
X.drop(columns=["Heart_Disease", "index"], axis=1, inplace=True)
X = pd.DataFrame(X)

# %%
# Random Forests in sklearn will automatically calculate feature importance
importance = rf_model.feature_importances_

# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.11852418451773611, 'EKG_results'),
#  (0.09304098996181889, 'Cholesterol'),
#  (0.08037219146976764, 'ST_depression'),
#  (0.06967342454992186, 'Sex'),
#  (0.06795028348447245, 'BP'),
#  (0.06775563132770517, 'Age'),
#  (0.047794655735333175, 'Exercise_angina'),
#  (0.03309049245565491, 'Chest_pain_type'),
#  (0.02879489652962605, 'Max_HR'),
#  (0.022298888200036424, 'Thallium'),
#  (0.012584400946873603, 'Slope_of_ST'),
#  (0.010649761086703513, 'FBS_over_120'),
#  (0.010186264895212075, 'Number_of_vessels_fluro')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>

# %%
#Trim less relevant columns from df

cols_to_drop = ['index', 'Exercise_angine', 'Chest_pain_type', 'Max_HR', 'Thallium', 'Slope_of_ST', 'FBS_over_120', 'Number_of_vessels_fluro']
trimmed_df = hd_df.drop(*cols_to_drop)

trimmed_df.show()
# Out:
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# |Age|Sex| BP|Cholesterol|EKG_results|Exercise_angina|ST_depression|Heart_Disease|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# | 70|  1|130|        322|          2|              0|            2|            1|
# | 67|  0|115|        564|          2|              0|            1|            0|
# | 57|  1|124|        261|          0|              0|            0|            1|
# | 64|  1|128|        263|          0|              1|            0|            0|
# | 74|  0|120|        269|          2|              1|            0|            0|
# | 65|  1|120|        177|          0|              0|            0|            0|
# | 56|  1|130|        256|          2|              1|            0|            1|
# | 59|  1|110|        239|          2|              1|            1|            1|
# | 60|  1|140|        293|          2|              0|            1|            1|
# | 63|  0|150|        407|          2|              0|            4|            1|
# | 59|  1|135|        234|          0|              0|            0|            0|
# | 53|  1|142|        226|          2|              1|            0|            0|
# | 44|  1|140|        235|          2|              0|            0|            0|
# | 61|  1|134|        234|          0|              0|            2|            1|
# | 57|  0|128|        303|          2|              0|            0|            0|
# | 71|  0|112|        149|          0|              0|            1|            0|
# | 46|  1|140|        311|          0|              1|            1|            1|
# | 53|  1|140|        203|          2|              1|            3|            1|
# | 64|  1|110|        211|          2|              1|            1|            0|
# | 40|  1|140|        199|          0|              1|            1|            0|
# +---+---+---+-----------+-----------+---------------+-------------+-------------+
# only showing top 20 rows

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Support Vector Machime

# %%
# Train the SVM model
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predictions
y_pred = svm_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7647058823529411

# %%
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# Calculating the accuracy score
acc_score = accuracy_score(y_test, y_pred)
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           29            9
# Actual 1            7           23
# Accuracy Score : 0.7647058823529411
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78        38
#            1       0.72      0.77      0.74        30
#
#     accuracy                           0.76        68
#    macro avg       0.76      0.76      0.76        68
# weighted avg       0.77      0.76      0.77        68
